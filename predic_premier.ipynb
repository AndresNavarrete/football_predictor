# %%
import pandas as pd 
import numpy as np
from datetime import datetime

# %%
## https://www.kaggle.com/datasets/irkaal/english-premier-league-results?resource=download
PREMIER_PATH = "data/results_premier/results.csv"

df = pd.read_csv(PREMIER_PATH, encoding = "ISO-8859-1")

# %%
def add_records(row):
    home = {
        'season': row.Season,
        'team': row.HomeTeam,
        'opponent': row.AwayTeam,
        'datetime': get_datetime(row.DateTime),
        'veneau': 'home',
        'GF': row.FTHG,
        'GA': row.FTAG,
        'result': get_match_result(row.FTHG, row.FTAG),
        'team_win_steak' :None,
        'team_no_win_steak' : None,
        'team_lose_steak' : None,
        'team_no_lose_steak': None,
    }

    away  = {
        'season': row.Season,
        'team': row.AwayTeam,
        'opponent': row.HomeTeam,
        'datetime': get_datetime(row.DateTime),
        'veneau': 'away',
        'GF': row.FTAG,
        'GA': row.FTHG,
        'result': get_match_result(row.FTAG, row.FTHG),
        'team_win_steak' :None,
        'team_no_win_steak' : None,
        'team_lose_steak' : None,
        'team_no_lose_steak': None,
    }
    all_records.extend([home,away])

def get_datetime(str):
    date_str = str.strip('Z').replace('T',' ')
    return datetime.strptime(date_str, '%Y-%m-%d %H:%M:%S')

def get_match_result(GF, GA):
    if GF == GA:
        return 'D'
    if GA > GF:
        return 'L'
    else:
        return 'W'

# %%
all_records = list()
df.apply(lambda row: add_records(row), axis=1)
matches = pd.DataFrame(all_records)

# %%
matches["team_code"] = matches.team.astype("category").cat.codes
matches["opp_code"] = matches.opponent.astype("category").cat.codes

# %%
groups = matches.groupby(["season", "team"])

# %%
for name, group in groups:
    print(f"{name} - {len(group)}")
# Out:
# ('1993-94', 'Arsenal') - 42
# ('1993-94', 'Aston Villa') - 42
# ('1993-94', 'Blackburn') - 42
# ('1993-94', 'Chelsea') - 42
# ('1993-94', 'Coventry') - 42
# ('1993-94', 'Everton') - 42
# ('1993-94', 'Ipswich') - 42
# ('1993-94', 'Leeds') - 42
# ('1993-94', 'Liverpool') - 42
# ('1993-94', 'Man City') - 42
# ('1993-94', 'Man United') - 42
# ('1993-94', 'Newcastle') - 42
# ('1993-94', 'Norwich') - 42
# ('1993-94', 'Oldham') - 42
# ('1993-94', 'QPR') - 42
# ('1993-94', 'Sheffield United') - 42
# ('1993-94', 'Sheffield Weds') - 42
# ('1993-94', 'Southampton') - 42
# ('1993-94', 'Swindon') - 42
# ('1993-94', 'Tottenham') - 42
# ('1993-94', 'West Ham') - 42
# ('1993-94', 'Wimbledon') - 42
# ('1994-95', 'Arsenal') - 42
# ('1994-95', 'Aston Villa') - 42
# ('1994-95', 'Blackburn') - 42
# ('1994-95', 'Chelsea') - 42
# ('1994-95', 'Coventry') - 42
# ('1994-95', 'Crystal Palace') - 42
# ('1994-95', 'Everton') - 42
# ('1994-95', 'Ipswich') - 42
# ('1994-95', 'Leeds') - 42
# ('1994-95', 'Leicester') - 42
# ('1994-95', 'Liverpool') - 42
# ('1994-95', 'Man City') - 42
# ('1994-95', 'Man United') - 42
# ('1994-95', 'Newcastle') - 42
# ('1994-95', 'Norwich') - 42
# ('1994-95', "Nott'm Forest") - 42
# ('1994-95', 'QPR') - 42
# ('1994-95', 'Sheffield Weds') - 42
# ('1994-95', 'Southampton') - 42
# ('1994-95', 'Tottenham') - 42
# ('1994-95', 'West Ham') - 42
# ('1994-95', 'Wimbledon') - 42
# ('1995-96', 'Arsenal') - 38
# ('1995-96', 'Aston Villa') - 38
# ('1995-96', 'Blackburn') - 38
# ('1995-96', 'Bolton') - 38
# ('1995-96', 'Chelsea') - 38
# ('1995-96', 'Coventry') - 38
# ('1995-96', 'Everton') - 38
# ('1995-96', 'Leeds') - 38
# ('1995-96', 'Liverpool') - 38
# ('1995-96', 'Man City') - 38
# ('1995-96', 'Man United') - 38
# ('1995-96', 'Middlesbrough') - 38
# ('1995-96', 'Newcastle') - 38
# ('1995-96', "Nott'm Forest") - 38
# ('1995-96', 'QPR') - 38
# ('1995-96', 'Sheffield Weds') - 38
# ('1995-96', 'Southampton') - 38
# ('1995-96', 'Tottenham') - 38
# ('1995-96', 'West Ham') - 38
# ('1995-96', 'Wimbledon') - 38
# ('1996-97', 'Arsenal') - 38
# ('1996-97', 'Aston Villa') - 38
# ('1996-97', 'Blackburn') - 38
# ('1996-97', 'Chelsea') - 38
# ('1996-97', 'Coventry') - 38
# ('1996-97', 'Derby') - 38
# ('1996-97', 'Everton') - 38
# ('1996-97', 'Leeds') - 38
# ('1996-97', 'Leicester') - 38
# ('1996-97', 'Liverpool') - 38
# ('1996-97', 'Man United') - 38
# ('1996-97', 'Middlesbrough') - 38
# ('1996-97', 'Newcastle') - 38
# ('1996-97', "Nott'm Forest") - 38
# ('1996-97', 'Sheffield Weds') - 38
# ('1996-97', 'Southampton') - 38
# ('1996-97', 'Sunderland') - 38
# ('1996-97', 'Tottenham') - 38
# ('1996-97', 'West Ham') - 38
# ('1996-97', 'Wimbledon') - 38
# ('1997-98', 'Arsenal') - 38
# ('1997-98', 'Aston Villa') - 38
# ('1997-98', 'Barnsley') - 38
# ('1997-98', 'Blackburn') - 38
# ('1997-98', 'Bolton') - 38
# ('1997-98', 'Chelsea') - 38
# ('1997-98', 'Coventry') - 38
# ('1997-98', 'Crystal Palace') - 38
# ('1997-98', 'Derby') - 38
# ('1997-98', 'Everton') - 38
# ('1997-98', 'Leeds') - 38
# ('1997-98', 'Leicester') - 38
# ('1997-98', 'Liverpool') - 38
# ('1997-98', 'Man United') - 38
# ('1997-98', 'Newcastle') - 38
# ('1997-98', 'Sheffield Weds') - 38
# ('1997-98', 'Southampton') - 38
# ('1997-98', 'Tottenham') - 38
# ('1997-98', 'West Ham') - 38
# ('1997-98', 'Wimbledon') - 38
# ('1998-99', 'Arsenal') - 38
# ('1998-99', 'Aston Villa') - 38
# ('1998-99', 'Blackburn') - 38
# ('1998-99', 'Charlton') - 38
# ('1998-99', 'Chelsea') - 38
# ('1998-99', 'Coventry') - 38
# ('1998-99', 'Derby') - 38
# ('1998-99', 'Everton') - 38
# ('1998-99', 'Leeds') - 38
# ('1998-99', 'Leicester') - 38
# ('1998-99', 'Liverpool') - 38
# ('1998-99', 'Man United') - 38
# ('1998-99', 'Middlesbrough') - 38
# ('1998-99', 'Newcastle') - 38
# ('1998-99', "Nott'm Forest") - 38
# ('1998-99', 'Sheffield Weds') - 38
# ('1998-99', 'Southampton') - 38
# ('1998-99', 'Tottenham') - 38
# ('1998-99', 'West Ham') - 38
# ('1998-99', 'Wimbledon') - 38
# ('1999-00', 'Arsenal') - 38
# ('1999-00', 'Aston Villa') - 38
# ('1999-00', 'Bradford') - 38
# ('1999-00', 'Chelsea') - 38
# ('1999-00', 'Coventry') - 38
# ('1999-00', 'Derby') - 38
# ('1999-00', 'Everton') - 38
# ('1999-00', 'Leeds') - 38
# ('1999-00', 'Leicester') - 38
# ('1999-00', 'Liverpool') - 38
# ('1999-00', 'Man United') - 38
# ('1999-00', 'Middlesbrough') - 38
# ('1999-00', 'Newcastle') - 38
# ('1999-00', 'Sheffield Weds') - 38
# ('1999-00', 'Southampton') - 38
# ('1999-00', 'Sunderland') - 38
# ('1999-00', 'Tottenham') - 38
# ('1999-00', 'Watford') - 38
# ('1999-00', 'West Ham') - 38
# ('1999-00', 'Wimbledon') - 38
# ('2000-01', 'Arsenal') - 38
# ('2000-01', 'Aston Villa') - 38
# ('2000-01', 'Bradford') - 38
# ('2000-01', 'Charlton') - 38
# ('2000-01', 'Chelsea') - 38
# ('2000-01', 'Coventry') - 38
# ('2000-01', 'Derby') - 38
# ('2000-01', 'Everton') - 38
# ('2000-01', 'Ipswich') - 38
# ('2000-01', 'Leeds') - 38
# ('2000-01', 'Leicester') - 38
# ('2000-01', 'Liverpool') - 38
# ('2000-01', 'Man City') - 38
# ('2000-01', 'Man United') - 38
# ('2000-01', 'Middlesbrough') - 38
# ('2000-01', 'Newcastle') - 38
# ('2000-01', 'Southampton') - 38
# ('2000-01', 'Sunderland') - 38
# ('2000-01', 'Tottenham') - 38
# ('2000-01', 'West Ham') - 38
# ('2001-02', 'Arsenal') - 38
# ('2001-02', 'Aston Villa') - 38
# ('2001-02', 'Blackburn') - 38
# ('2001-02', 'Bolton') - 38
# ('2001-02', 'Charlton') - 38
# ('2001-02', 'Chelsea') - 38
# ('2001-02', 'Derby') - 38
# ('2001-02', 'Everton') - 38
# ('2001-02', 'Fulham') - 38
# ('2001-02', 'Ipswich') - 38
# ('2001-02', 'Leeds') - 38
# ('2001-02', 'Leicester') - 38
# ('2001-02', 'Liverpool') - 38
# ('2001-02', 'Man United') - 38
# ('2001-02', 'Middlesbrough') - 38
# ('2001-02', 'Newcastle') - 38
# ('2001-02', 'Southampton') - 38
# ('2001-02', 'Sunderland') - 38
# ('2001-02', 'Tottenham') - 38
# ('2001-02', 'West Ham') - 38
# ('2002-03', 'Arsenal') - 38
# ('2002-03', 'Aston Villa') - 38
# ('2002-03', 'Birmingham') - 38
# ('2002-03', 'Blackburn') - 38
# ('2002-03', 'Bolton') - 38
# ('2002-03', 'Charlton') - 38
# ('2002-03', 'Chelsea') - 38
# ('2002-03', 'Everton') - 38
# ('2002-03', 'Fulham') - 38
# ('2002-03', 'Leeds') - 38
# ('2002-03', 'Liverpool') - 38
# ('2002-03', 'Man City') - 38
# ('2002-03', 'Man United') - 38
# ('2002-03', 'Middlesbrough') - 38
# ('2002-03', 'Newcastle') - 38
# ('2002-03', 'Southampton') - 38
# ('2002-03', 'Sunderland') - 38
# ('2002-03', 'Tottenham') - 38
# ('2002-03', 'West Brom') - 38
# ('2002-03', 'West Ham') - 38
# ('2003-04', 'Arsenal') - 38
# ('2003-04', 'Aston Villa') - 38
# ('2003-04', 'Birmingham') - 38
# ('2003-04', 'Blackburn') - 38
# ('2003-04', 'Bolton') - 38
# ('2003-04', 'Charlton') - 38
# ('2003-04', 'Chelsea') - 38
# ('2003-04', 'Everton') - 38
# ('2003-04', 'Fulham') - 38
# ('2003-04', 'Leeds') - 38
# ('2003-04', 'Leicester') - 38
# ('2003-04', 'Liverpool') - 38
# ('2003-04', 'Man City') - 38
# ('2003-04', 'Man United') - 38
# ('2003-04', 'Middlesbrough') - 38
# ('2003-04', 'Newcastle') - 38
# ('2003-04', 'Portsmouth') - 38
# ('2003-04', 'Southampton') - 38
# ('2003-04', 'Tottenham') - 38
# ('2003-04', 'Wolves') - 38
# ('2004-05', 'Arsenal') - 38
# ('2004-05', 'Aston Villa') - 38
# ('2004-05', 'Birmingham') - 38
# ('2004-05', 'Blackburn') - 38
# ('2004-05', 'Bolton') - 38
# ('2004-05', 'Charlton') - 38
# ('2004-05', 'Chelsea') - 38
# ('2004-05', 'Crystal Palace') - 38
# ('2004-05', 'Everton') - 38
# ('2004-05', 'Fulham') - 38
# ('2004-05', 'Liverpool') - 38
# ('2004-05', 'Man City') - 38
# ('2004-05', 'Man United') - 38
# ('2004-05', 'Middlesbrough') - 38
# ('2004-05', 'Newcastle') - 38
# ('2004-05', 'Norwich') - 38
# ('2004-05', 'Portsmouth') - 38
# ('2004-05', 'Southampton') - 38
# ('2004-05', 'Tottenham') - 38
# ('2004-05', 'West Brom') - 38
# ('2005-06', 'Arsenal') - 38
# ('2005-06', 'Aston Villa') - 38
# ('2005-06', 'Birmingham') - 38
# ('2005-06', 'Blackburn') - 38
# ('2005-06', 'Bolton') - 38
# ('2005-06', 'Charlton') - 38
# ('2005-06', 'Chelsea') - 38
# ('2005-06', 'Everton') - 38
# ('2005-06', 'Fulham') - 38
# ('2005-06', 'Liverpool') - 38
# ('2005-06', 'Man City') - 38
# ('2005-06', 'Man United') - 38
# ('2005-06', 'Middlesbrough') - 38
# ('2005-06', 'Newcastle') - 38
# ('2005-06', 'Portsmouth') - 38
# ('2005-06', 'Sunderland') - 38
# ('2005-06', 'Tottenham') - 38
# ('2005-06', 'West Brom') - 38
# ('2005-06', 'West Ham') - 38
# ('2005-06', 'Wigan') - 38
# ('2006-07', 'Arsenal') - 38
# ('2006-07', 'Aston Villa') - 38
# ('2006-07', 'Blackburn') - 38
# ('2006-07', 'Bolton') - 38
# ('2006-07', 'Charlton') - 38
# ('2006-07', 'Chelsea') - 38
# ('2006-07', 'Everton') - 38
# ('2006-07', 'Fulham') - 38
# ('2006-07', 'Liverpool') - 38
# ('2006-07', 'Man City') - 38
# ('2006-07', 'Man United') - 38
# ('2006-07', 'Middlesbrough') - 38
# ('2006-07', 'Newcastle') - 38
# ('2006-07', 'Portsmouth') - 38
# ('2006-07', 'Reading') - 38
# ('2006-07', 'Sheffield United') - 38
# ('2006-07', 'Tottenham') - 38
# ('2006-07', 'Watford') - 38
# ('2006-07', 'West Ham') - 38
# ('2006-07', 'Wigan') - 38
# ('2007-08', 'Arsenal') - 38
# ('2007-08', 'Aston Villa') - 38
# ('2007-08', 'Birmingham') - 38
# ('2007-08', 'Blackburn') - 38
# ('2007-08', 'Bolton') - 38
# ('2007-08', 'Chelsea') - 38
# ('2007-08', 'Derby') - 38
# ('2007-08', 'Everton') - 38
# ('2007-08', 'Fulham') - 38
# ('2007-08', 'Liverpool') - 38
# ('2007-08', 'Man City') - 38
# ('2007-08', 'Man United') - 38
# ('2007-08', 'Middlesbrough') - 38
# ('2007-08', 'Newcastle') - 38
# ('2007-08', 'Portsmouth') - 38
# ('2007-08', 'Reading') - 38
# ('2007-08', 'Sunderland') - 38
# ('2007-08', 'Tottenham') - 38
# ('2007-08', 'West Ham') - 38
# ('2007-08', 'Wigan') - 38
# ('2008-09', 'Arsenal') - 38
# ('2008-09', 'Aston Villa') - 38
# ('2008-09', 'Blackburn') - 38
# ('2008-09', 'Bolton') - 38
# ('2008-09', 'Chelsea') - 38
# ('2008-09', 'Everton') - 38
# ('2008-09', 'Fulham') - 38
# ('2008-09', 'Hull') - 38
# ('2008-09', 'Liverpool') - 38
# ('2008-09', 'Man City') - 38
# ('2008-09', 'Man United') - 38
# ('2008-09', 'Middlesbrough') - 38
# ('2008-09', 'Newcastle') - 38
# ('2008-09', 'Portsmouth') - 38
# ('2008-09', 'Stoke') - 38
# ('2008-09', 'Sunderland') - 38
# ('2008-09', 'Tottenham') - 38
# ('2008-09', 'West Brom') - 38
# ('2008-09', 'West Ham') - 38
# ('2008-09', 'Wigan') - 38
# ('2009-10', 'Arsenal') - 38
# ('2009-10', 'Aston Villa') - 38
# ('2009-10', 'Birmingham') - 38
# ('2009-10', 'Blackburn') - 38
# ('2009-10', 'Bolton') - 38
# ('2009-10', 'Burnley') - 38
# ('2009-10', 'Chelsea') - 38
# ('2009-10', 'Everton') - 38
# ('2009-10', 'Fulham') - 38
# ('2009-10', 'Hull') - 38
# ('2009-10', 'Liverpool') - 38
# ('2009-10', 'Man City') - 38
# ('2009-10', 'Man United') - 38
# ('2009-10', 'Portsmouth') - 38
# ('2009-10', 'Stoke') - 38
# ('2009-10', 'Sunderland') - 38
# ('2009-10', 'Tottenham') - 38
# ('2009-10', 'West Ham') - 38
# ('2009-10', 'Wigan') - 38
# ('2009-10', 'Wolves') - 38
# ('2010-11', 'Arsenal') - 38
# ('2010-11', 'Aston Villa') - 38
# ('2010-11', 'Birmingham') - 38
# ('2010-11', 'Blackburn') - 38
# ('2010-11', 'Blackpool') - 38
# ('2010-11', 'Bolton') - 38
# ('2010-11', 'Chelsea') - 38
# ('2010-11', 'Everton') - 38
# ('2010-11', 'Fulham') - 38
# ('2010-11', 'Liverpool') - 38
# ('2010-11', 'Man City') - 38
# ('2010-11', 'Man United') - 38
# ('2010-11', 'Newcastle') - 38
# ('2010-11', 'Stoke') - 38
# ('2010-11', 'Sunderland') - 38
# ('2010-11', 'Tottenham') - 38
# ('2010-11', 'West Brom') - 38
# ('2010-11', 'West Ham') - 38
# ('2010-11', 'Wigan') - 38
# ('2010-11', 'Wolves') - 38
# ('2011-12', 'Arsenal') - 38
# ('2011-12', 'Aston Villa') - 38
# ('2011-12', 'Blackburn') - 38
# ('2011-12', 'Bolton') - 38
# ('2011-12', 'Chelsea') - 38
# ('2011-12', 'Everton') - 38
# ('2011-12', 'Fulham') - 38
# ('2011-12', 'Liverpool') - 38
# ('2011-12', 'Man City') - 38
# ('2011-12', 'Man United') - 38
# ('2011-12', 'Newcastle') - 38
# ('2011-12', 'Norwich') - 38
# ('2011-12', 'QPR') - 38
# ('2011-12', 'Stoke') - 38
# ('2011-12', 'Sunderland') - 38
# ('2011-12', 'Swansea') - 38
# ('2011-12', 'Tottenham') - 38
# ('2011-12', 'West Brom') - 38
# ('2011-12', 'Wigan') - 38
# ('2011-12', 'Wolves') - 38
# ('2012-13', 'Arsenal') - 38
# ('2012-13', 'Aston Villa') - 38
# ('2012-13', 'Chelsea') - 38
# ('2012-13', 'Everton') - 38
# ('2012-13', 'Fulham') - 38
# ('2012-13', 'Liverpool') - 38
# ('2012-13', 'Man City') - 38
# ('2012-13', 'Man United') - 38
# ('2012-13', 'Newcastle') - 38
# ('2012-13', 'Norwich') - 38
# ('2012-13', 'QPR') - 38
# ('2012-13', 'Reading') - 38
# ('2012-13', 'Southampton') - 38
# ('2012-13', 'Stoke') - 38
# ('2012-13', 'Sunderland') - 38
# ('2012-13', 'Swansea') - 38
# ('2012-13', 'Tottenham') - 38
# ('2012-13', 'West Brom') - 38
# ('2012-13', 'West Ham') - 38
# ('2012-13', 'Wigan') - 38
# ('2013-14', 'Arsenal') - 38
# ('2013-14', 'Aston Villa') - 38
# ('2013-14', 'Cardiff') - 38
# ('2013-14', 'Chelsea') - 38
# ('2013-14', 'Crystal Palace') - 38
# ('2013-14', 'Everton') - 38
# ('2013-14', 'Fulham') - 38
# ('2013-14', 'Hull') - 38
# ('2013-14', 'Liverpool') - 38
# ('2013-14', 'Man City') - 38
# ('2013-14', 'Man United') - 38
# ('2013-14', 'Newcastle') - 38
# ('2013-14', 'Norwich') - 38
# ('2013-14', 'Southampton') - 38
# ('2013-14', 'Stoke') - 38
# ('2013-14', 'Sunderland') - 38
# ('2013-14', 'Swansea') - 38
# ('2013-14', 'Tottenham') - 38
# ('2013-14', 'West Brom') - 38
# ('2013-14', 'West Ham') - 38
# ('2014-15', 'Arsenal') - 38
# ('2014-15', 'Aston Villa') - 38
# ('2014-15', 'Burnley') - 38
# ('2014-15', 'Chelsea') - 38
# ('2014-15', 'Crystal Palace') - 38
# ('2014-15', 'Everton') - 38
# ('2014-15', 'Hull') - 38
# ('2014-15', 'Leicester') - 38
# ('2014-15', 'Liverpool') - 38
# ('2014-15', 'Man City') - 38
# ('2014-15', 'Man United') - 38
# ('2014-15', 'Newcastle') - 38
# ('2014-15', 'QPR') - 38
# ('2014-15', 'Southampton') - 38
# ('2014-15', 'Stoke') - 38
# ('2014-15', 'Sunderland') - 38
# ('2014-15', 'Swansea') - 38
# ('2014-15', 'Tottenham') - 38
# ('2014-15', 'West Brom') - 38
# ('2014-15', 'West Ham') - 38
# ('2015-16', 'Arsenal') - 38
# ('2015-16', 'Aston Villa') - 38
# ('2015-16', 'Bournemouth') - 38
# ('2015-16', 'Chelsea') - 38
# ('2015-16', 'Crystal Palace') - 38
# ('2015-16', 'Everton') - 38
# ('2015-16', 'Leicester') - 38
# ('2015-16', 'Liverpool') - 38
# ('2015-16', 'Man City') - 38
# ('2015-16', 'Man United') - 38
# ('2015-16', 'Newcastle') - 38
# ('2015-16', 'Norwich') - 38
# ('2015-16', 'Southampton') - 38
# ('2015-16', 'Stoke') - 38
# ('2015-16', 'Sunderland') - 38
# ('2015-16', 'Swansea') - 38
# ('2015-16', 'Tottenham') - 38
# ('2015-16', 'Watford') - 38
# ('2015-16', 'West Brom') - 38
# ('2015-16', 'West Ham') - 38
# ('2016-17', 'Arsenal') - 38
# ('2016-17', 'Bournemouth') - 38
# ('2016-17', 'Burnley') - 38
# ('2016-17', 'Chelsea') - 38
# ('2016-17', 'Crystal Palace') - 38
# ('2016-17', 'Everton') - 38
# ('2016-17', 'Hull') - 38
# ('2016-17', 'Leicester') - 38
# ('2016-17', 'Liverpool') - 38
# ('2016-17', 'Man City') - 38
# ('2016-17', 'Man United') - 38
# ('2016-17', 'Middlesbrough') - 38
# ('2016-17', 'Southampton') - 38
# ('2016-17', 'Stoke') - 38
# ('2016-17', 'Sunderland') - 38
# ('2016-17', 'Swansea') - 38
# ('2016-17', 'Tottenham') - 38
# ('2016-17', 'Watford') - 38
# ('2016-17', 'West Brom') - 38
# ('2016-17', 'West Ham') - 38
# ('2017-18', 'Arsenal') - 38
# ('2017-18', 'Bournemouth') - 38
# ('2017-18', 'Brighton') - 38
# ('2017-18', 'Burnley') - 38
# ('2017-18', 'Chelsea') - 38
# ('2017-18', 'Crystal Palace') - 38
# ('2017-18', 'Everton') - 38
# ('2017-18', 'Huddersfield') - 38
# ('2017-18', 'Leicester') - 38
# ('2017-18', 'Liverpool') - 38
# ('2017-18', 'Man City') - 38
# ('2017-18', 'Man United') - 38
# ('2017-18', 'Newcastle') - 38
# ('2017-18', 'Southampton') - 38
# ('2017-18', 'Stoke') - 38
# ('2017-18', 'Swansea') - 38
# ('2017-18', 'Tottenham') - 38
# ('2017-18', 'Watford') - 38
# ('2017-18', 'West Brom') - 38
# ('2017-18', 'West Ham') - 38
# ('2018-19', 'Arsenal') - 38
# ('2018-19', 'Bournemouth') - 38
# ('2018-19', 'Brighton') - 38
# ('2018-19', 'Burnley') - 38
# ('2018-19', 'Cardiff') - 38
# ('2018-19', 'Chelsea') - 38
# ('2018-19', 'Crystal Palace') - 38
# ('2018-19', 'Everton') - 38
# ('2018-19', 'Fulham') - 38
# ('2018-19', 'Huddersfield') - 38
# ('2018-19', 'Leicester') - 38
# ('2018-19', 'Liverpool') - 38
# ('2018-19', 'Man City') - 38
# ('2018-19', 'Man United') - 38
# ('2018-19', 'Newcastle') - 38
# ('2018-19', 'Southampton') - 38
# ('2018-19', 'Tottenham') - 38
# ('2018-19', 'Watford') - 38
# ('2018-19', 'West Ham') - 38
# ('2018-19', 'Wolves') - 38
# ('2019-20', 'Arsenal') - 38
# ('2019-20', 'Aston Villa') - 38
# ('2019-20', 'Bournemouth') - 38
# ('2019-20', 'Brighton') - 38
# ('2019-20', 'Burnley') - 38
# ('2019-20', 'Chelsea') - 38
# ('2019-20', 'Crystal Palace') - 38
# ('2019-20', 'Everton') - 38
# ('2019-20', 'Leicester') - 38
# ('2019-20', 'Liverpool') - 38
# ('2019-20', 'Man City') - 38
# ('2019-20', 'Man United') - 38
# ('2019-20', 'Newcastle') - 38
# ('2019-20', 'Norwich') - 38
# ('2019-20', 'Sheffield United') - 38
# ('2019-20', 'Southampton') - 38
# ('2019-20', 'Tottenham') - 38
# ('2019-20', 'Watford') - 38
# ('2019-20', 'West Ham') - 38
# ('2019-20', 'Wolves') - 38
# ('2020-21', 'Arsenal') - 38
# ('2020-21', 'Aston Villa') - 38
# ('2020-21', 'Brighton') - 38
# ('2020-21', 'Burnley') - 38
# ('2020-21', 'Chelsea') - 38
# ('2020-21', 'Crystal Palace') - 38
# ('2020-21', 'Everton') - 38
# ('2020-21', 'Fulham') - 38
# ('2020-21', 'Leeds') - 38
# ('2020-21', 'Leicester') - 38
# ('2020-21', 'Liverpool') - 38
# ('2020-21', 'Man City') - 38
# ('2020-21', 'Man United') - 38
# ('2020-21', 'Newcastle') - 38
# ('2020-21', 'Sheffield United') - 38
# ('2020-21', 'Southampton') - 38
# ('2020-21', 'Tottenham') - 38
# ('2020-21', 'West Brom') - 38
# ('2020-21', 'West Ham') - 38
# ('2020-21', 'Wolves') - 38
# ('2021-22', 'Arsenal') - 30
# ('2021-22', 'Aston Villa') - 31
# ('2021-22', 'Brentford') - 32
# ('2021-22', 'Brighton') - 31
# ('2021-22', 'Burnley') - 30
# ('2021-22', 'Chelsea') - 30
# ('2021-22', 'Crystal Palace') - 31
# ('2021-22', 'Everton') - 30
# ('2021-22', 'Leeds') - 32
# ('2021-22', 'Leicester') - 29
# ('2021-22', 'Liverpool') - 31
# ('2021-22', 'Man City') - 31
# ('2021-22', 'Man United') - 31
# ('2021-22', 'Newcastle') - 31
# ('2021-22', 'Norwich') - 31
# ('2021-22', 'Southampton') - 31
# ('2021-22', 'Tottenham') - 31
# ('2021-22', 'Watford') - 31
# ('2021-22', 'West Ham') - 32
# ('2021-22', 'Wolves') - 32
